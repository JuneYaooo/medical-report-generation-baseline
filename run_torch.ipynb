# %%
# K80 gpu for 12 hours
import torch
print('GPU:', torch.cuda.is_available())
torch.manual_seed(555)
! /opt/bin/nvidia-smi
# Out:
# GPU: True
# Wed Apr  7 07:38:48 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r '/content/drive/MyDrive/!CS_23-1_Workspace/Coding_Implementation/medical_image_dataset/iu_xray/iu_xray_images' '/content/drive/MyDrive/Medical-Report-Generation/data'

# %%
import os
os.chdir("/content/drive/MyDrive/Medical-Report-Generation")

# %%
# !python trainer.py
# Out:
# 2021-04-05 10:35:31.296721: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-05 10:35:42.164856: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-05 10:35:42.164989: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-05 10:35:42.165133: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-05 10:35:42.165705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %%
# !python tester.py
# Out:
# Namespace(attention_version='v4', batch_size=8, cam_size=224, caption_json='./data/new_data/captions.json', classes=210, cuda=True, dropout=0.1, embed_size=512, file_lits='./data/new_data/test_data.txt', generate_dir='cam', hidden_size=512, image_dir='./data/images', k=10, lambda_stop=10, lambda_tag=10000, lambda_word=1, load_model_path='train_best_loss.pth.tar', model_dir='./report_v4_models/v4/20210405-10:35', momentum=0.1, n_max=30, pretrained=False, resize=224, result_name='debug', result_path='results', s_max=6, sementic_features_dim=512, sent_version='v1', sentence_num_layers=2, visual_model_name='resnet152', vocab_path='./data/new_data/vocab.pkl', word_num_layers=1)
# [Load Model-train_best_loss.pth.tar Succeed!]
# Load From Epoch 4
# Visual Extractor Loaded!
# MLC Loaded!
# Co-Attention Loaded!
# Sentence Model Loaded!
# Word Model Loaded!
# Generating: 100% 61/61 [06:47<00:00,  6.69s/it]

# %%
# !python metric_performance.py
# Out:
# before evaluate
# PTBTokenizer tokenized 17974 tokens at 92026.61 tokens per second.
# PTBTokenizer tokenized 17947 tokens at 80445.28 tokens per second.
# {'testlen': 15050, 'reflen': 15565, 'guess': [15050, 14567, 14084, 13601], 'correct': [5014, 1914, 844, 320]}
# ratio: 0.9669129457114701
#
# IU-XRAY Test Dataset Evaluation Metrics & Scores:
# Bleu_1 0.32195
# Bleu_2 0.20218
# Bleu_3 0.13328
# Bleu_4 0.08565
# ROUGE_L 0.25532
# CIDEr 0.18119

# %%
import tensorflow as tf
import torch
import numpy as np
import scipy.misc 
try:
    from StringIO import StringIO  # Python 2.7
except ImportError:
    from io import BytesIO         # Python 3.x

# %%
class Logger(object):
    
    def __init__(self, log_dir):
        """Create a summary writer logging to log_dir."""
        self.writer = tf.summary.create_file_writer(log_dir)

    def scalar_summary(self, tag, value, step):
        """Log a scalar variable."""
        print("start logger:")
        print("tag:",tag)
        print("value:",value)
        print("step:",step)
        with self.writer.as_default():
            tf.summary.scalar(tag, value, step=step)
            self.writer.flush()
        # summary = tf.Summary(value=[tf.Summary.Value(tag=tag, simple_value=value)])
        # self.writer.add_summary(summary, step)

# %%
# !dir
# Out:
# data		       report_v4_models		 sample.py
# debugger.py	       results			 tensorboard.sh
# metric_performance.py  review_captions.ipynb	 tester.py
# pycocoevalcap	       review_performance.ipynb  trainer.py
# README.md	       run_torch.ipynb		 utils

# %%
logg=Logger("tlogs")
ttag="train tags loss"
tvalue=torch.tensor(12093.3379, device='cuda:0').cpu()
tstep=1
logg.scalar_summary(ttag, tvalue, tstep)
# Out:
# start logger:
# tag: train tags loss
# value: tensor(12093.3379)
# step: 1
